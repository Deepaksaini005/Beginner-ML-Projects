# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "Student": ["Aarav", "Aditi", "Rohan", "Sneha", "Karan", "Priya", "Rahul", "Neha", "Vikram", "Ananya", "Arjun", "Pooja", "Ishita", "Mohit", "Simran"],
    "Study_Hours": [2, 3, 4, 5, 7, 8, 6, 2, 9, 1, 3, 7, 8, 4, 5],
    "Attendance": [65, 70, 78, 82, 90, 92, 85, 68, 95, 60, 72, 89, 94, 76, 84],
    "Assignments_Submitted": [4, 5, 6, 7, 9, 10, 8, 4, 10, 3, 5, 9, 10, 6, 7],
    "Mock_Test_Score": [45, 50, 58, 64, 82, 88, 75, 47, 93, 40, 52, 80, 91, 60, 68]
}

df = pd.DataFrame(data)

df.to_csv("student_performance.csv", index=False)

print("CSV file created successfully!")
# Out:
# CSV file created successfully!

# %%
import pandas as pd

data = {
    "Customer_ID": ["C101","C102","C103","C104","C105","C106","C107","C108","C109","C110","C111","C112","C113","C114","C115"],
    "Age": [19,22,24,27,30,35,40,45,29,33,38,42,26,31,48],
    "Monthly_Income": [18000,22000,25000,32000,45000,60000,75000,90000,42000,55000,70000,85000,30000,50000,95000],
    "Phones_Bought": [1,1,2,2,3,4,5,5,3,4,4,5,2,3,6],
    "Average_Spending": [12000,15000,18000,25000,35000,50000,65000,78000,32000,47000,60000,73000,22000,40000,85000]
}

df = pd.DataFrame(data)

df.to_csv("customer_phone_data.csv", index=False)

print("customer_phone_data.csv created successfully!")
# Out:
# customer_phone_data.csv created successfully!
