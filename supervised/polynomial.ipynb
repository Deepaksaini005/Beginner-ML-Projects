# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt

# %%
data = {
    "House_Size":[500,700,900,1100,1300,1500,1700,1900,2100,2300,2500,2700,2900,3100,3300],
    "Price":[15,20,28,40,56,76,100,128,160,196,236,280,328,380,436]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     House_Size  Price
# 0          500     15
# 1          700     20
# 2          900     28
# 3         1100     40
# 4         1300     56
# 5         1500     76
# 6         1700    100
# 7         1900    128
# 8         2100    160
# 9         2300    196
# 10        2500    236
# 11        2700    280
# 12        2900    328
# 13        3100    380
# 14        3300    436

# %%
plt.figure(figsize=(6,4))
plt.scatter(x  =df['House_Size'], y=df['Price'], color='blue')

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

x = df[['House_Size']]
y = df['Price']

poly = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(x_poly, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)

pred = model.predict(x_test)

print('Predictions:', pred)
print('R² Score:', r2_score(y_test, pred))

print(pred([[5466]]))
# Out:
# Predictions: [196. 280.  16.]
# R² Score: 0.9999727376819759
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 22
#      18
#      19 print('Predictions:', pred)
#      20 print('R² Score:', r2_score(y_test, pred))
#      21
# ---> 22 print(pred([[5466]]))
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
model = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([227.77242197, 292.5784275 , -63.85460292])

# %%
print('Predictions:', y_pred)
# Out:
# Predictions: [227.77242197 292.5784275  -63.85460292]
