# %%
import pandas as pd

from sklearn.cluster import AgglomerativeClustering

# Create a numeric dataset for hierarchical clustering
data = {
    "X": [1, 1.5, 3, 3.5, 10, 10.5, 11, 11.5, 15, 15.5],
    "Y": [1, 2, 3, 4, 10, 11, 12, 13, 20, 21],
}

df = pd.DataFrame(data)

# Create Hierarchical Clustering model
model = AgglomerativeClustering(
    n_clusters=2,
    metric="euclidean",
    linkage="ward",
)

# Train the model and assign clusters
clusters = model.fit_predict(df)

# Add cluster labels to the dataset
df["Cluster"] = clusters

# Display the result
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2
#       3 from sklearn.cluster import AgglomerativeClustering
#       4
#
# ModuleNotFoundError: No module named 'pandas'
