# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import warnings

# %%
# Dataset
data = {
    "Study": ["High","High","Low","Low","High"],
    "Attendance": ["High","Low","High","Low","High"],
    "Passed": ["Yes","Yes","No","No","Yes"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Study Attendance Passed
# 0  High       High    Yes
# 1  High        Low    Yes
# 2   Low       High     No
# 3   Low        Low     No
# 4  High       High    Yes

# %%
# study_encoder = LabelEncoder()
# attendance_encoder = LabelEncoder()
# pass_encoder = LabelEncoder()

# df["Study"] = study_encoder.fit_transform(df["Study"])
# df["Attendance"] = attendance_encoder.fit_transform(df["Attendance"])
# df["Passed"] = pass_encoder.fit_transform(df["Passed"])

# print(df)

# %%
labels = LabelEncoder()
print(df)
# Out:
#    Study  Attendance  Passed
# 0      0           0       1
# 1      0           1       1
# 2      1           0       0
# 3      1           1       0
# 4      0           0       1

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

# %%
x = df[["Study", "Attendance"]]
y = df["Passed"]

# %%
model.fit(x, y)
y_pred = model.predict(x)
print(y_pred)

print("Accuracy:", model.score(x, y))

print("Predicted values:", y_pred[1])
# Out:
# [1 1 0 0 1]
# Accuracy: 1.0
# Predicted values: 1

# %%
model1 = GaussianNB()
model1.fit(x, y)
y_pred = model1.predict(x)
print(y_pred)
# Out:
# [1 1 0 0 1]

# %%
from sklearn.naive_bayes import BernoulliNB
model2 = BernoulliNB()
model2.fit(x, y)
y_pred = model2.predict(x)

# %%
y_pred
# Out:
# array([1, 1, 0, 0, 1])

# %%
print("Accuracy:", model2.score(x, y))
# Out:
# Accuracy: 1.0

# %%
print("Predicted values:", y_pred[1])
# Out:
# Predicted values: 1
